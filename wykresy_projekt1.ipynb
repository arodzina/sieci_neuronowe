# %%
import pandas as pd
df=pd.read_csv("train_data.csv",sep=";")
print(max(df['Admission_Deposit']))
import pandas as pd

# Przykład danych
# df = pd.read_csv("twoj_plik.csv")  # lub masz już df

# Łączenie klas "Stay" powyżej 40 w jedną kategorię "40+"
df['Stay_cleaned'] = df['Stay'].replace({
    '41-50': '40+',
    '51-60': '40+',
    '61-70': '40+',
    '71-80': '40+',
    '81-90': '40+',
    '91-100': '40+',
    'More than 100 Days': '40+'
})
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='Admission_Deposit', fill=True, color='skyblue')

plt.title("Krzywa gęstości wpłat przy przyjęciu")
plt.xlabel("Wpłata przy przyjęciu")
plt.ylabel("Gęstość")
plt.tight_layout()
plt.show()
print(np.median(df['Admission_Deposit']))
print(np.mean(df['Admission_Deposit']))
from scipy.stats import skew
skosnosc = skew(df['Admission_Deposit'], nan_policy='omit')
print(skosnosc)
# Out:
# 11008.0
# 4741.0
# 4880.749392346391
# 0.9314497411311059
